# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonea/Biostats2026/blob/main/Exams/Exam2_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <a name="Exam2intro">Exam 2: Computer Section (40% of grade)</a>
# ---
#
# This section is open note and computer, but AI assistance is **NOT** permitted. After you are done, print to .pdf and upload your file in canvas. Good luck!!

# %% [markdown]
# ## <a name="Exam2">Problem 1</a>
#
# ---
#
# Draw 5 random samples from the standard normal distribution (size **n = 5**).  Calculate the mean of these 5 random samples. Repeat this process 10,000 times and store the resulting 10,000 mean values in a vector.
#
# (i) Create a histogram plot of the vector containing the 10,000 means.
#
# (ii) From this vector of the means, find the expected (average) value and standard deviation (otherwise known as the standard error of the mean).
#
# <br>
#
# #### <a name="02sol2">Solution to Problem 1</a>
#
# ---
#
# <br>
# <br>

# %%
# code for problem 1
set.seed(23) #keep this command so everyone's answers are the same

# %% [markdown]
# ## <a name="Exam1">Problem 2</a>
#
# ---
#
# Repeat the steps in Problem 1 but now drawing a random sample of size n = 20.
#
# <br>
#
# #### <a name="02sol3">Solution to Problem 2</a>
#
# ---
#
# <br>
# <br>

# %%
# code for problem 2
set.seed(0) #keep this command so everyone's answers are the same

# %% [markdown]
# ## <a name="Exam1">Problem 3</a>
#
# ---
#
# (i) What value of the standard error do you expect using the theoretical equation for the standard normal distribution for sample sizes of n = 5 and n = 20.
#
# (ii) Comment on how this compares with the standard error you calculated in Problems 1 and 2.
#
# <br>
#
# #### <a name="02sol4">Solution to Problem 3</a>
#
# ---
#
# <br>

# %%
# code for problem 3

# %% [markdown]
# ## <a name="Exam1">Problem 4</a>
#
# ---
#
# A clinical trial was conducted to test the efficacy of nifedipine, a new drug for reducing chest pain in patients with angina severe enough to require hospitalization. The main objective of the study was to compare the degree of pain relief with nifedipine vs. propranolol (a standard medication). A secondary objective was to better understand the effects of these medications on other physiologic parameters, including heart rate and blood pressure. Data on these parameters are given in the Dataset NIFED.DAT.csv.
#
# First load the data and sort it by executing the code cells below.

# %%
#load NIFED dataset
trial <- read.csv("https://raw.githubusercontent.com/gibsonea/Biostats/main/Datasets/NIFED.DAT.csv")

# %%
#Execute this code cell to sort data into two separate vectors for the difference
# in heart rate after being on the medication for 5 days for
#the two medications: nifedipine, propranolol. Output are the vectors
# dHR.N and dHR.P

dHR.N = trial$dHR[trial$trtgrp=="N"]
dHR.P = trial$dHR[trial$trtgrp=="P"]
str(dHR.N)
str(dHR.P)

# %% [markdown]
# ## <a name="Exam1">Problem 4a</a>
#
# ---
#
# Find the 95% Confidence Interval for the change in heart rate for patients on nifedipine. From your CI, what do you conclude?
#
#
#
#
# #### <a name="02sol5">Solution to Problem 4a</a>
#
# ---
#
# <br>
# <br>

# %%
# Code cell for Problem 4a

# %% [markdown]
# ## <a name="Exam1">Problem 4b</a>
#
# ---
#
# Find the 95% Confidence Interval for the change in heart rate for patients on propranolol. From your CI, what do you conclude?
#
#
#
#
# #### <a name="02sol4b">Solution to Problem 4b</a>
#
# ---
#
# <br>
# <br>

# %%
# Code cell for problem 4b
