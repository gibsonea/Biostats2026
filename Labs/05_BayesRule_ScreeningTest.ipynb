# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonea/Biostats/blob/main/Labs/05_BayesRule_ScreeningTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <a name="05intro">2.2: Bayes' Rule and Screening Tests</a>
#
# ----
#
# Medical screening is an essential part of disease prevention. Primary care screening tests are less invasive (e.g., mammograms or blood tests), but do not always have the best accuracy. In an ideal world, a test will always predict reality correctly 100% of the time. Unfortunately, perfect tests do not exist - there is simply too much variability in human biology to make that possible.
#
# Typically, if a patient tests positive in primary care, they will undergo a secondary care test that is more invasive, but also more accurate (e.g., a biopsy). Understanding the statistics behind screening tests and how these tests are used in medical decisions is important for any biomedical engineer.
#
# <br>
#
# ###What can go wrong when testing for something?
#
# What a test predicts can be different from reality in two main ways:
#
# A <font color="mediumseagreen">**False Positive**</font> *(FP of F+)* is when a **test result is positive** for a condition that a **patient does NOT actually have**.
# - Example: a blood test resulting positive for diabetes when the patient does not actually have diabetes.
#
# A <font color="mediumseagreen">**False Negative**</font> *(FN of F-)* is when a a **test result is negative** for a condition that a **patient actually DOES have**.
# - Example: a blood test resulting negative for diabetes when the patient does actually have diabetes.
#
# ### Fortunately, there are also the scenarios when the test does get it right:
#
# - A <font color="mediumseagreen">**True Positive**</font> *(TP or T+)* is when a test result is positive for a condition that a patient DOES have.
#
# - A <font color="mediumseagreen">**True Negative**</font> *(TN or T-)* is when a test result is negative for a condition that a patient does NOT have.
#
# <br>
#
# These concepts can be summarized in something called a <font color="mediumseagreen">contingency table</font>.
#
# <img src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/confmatr.png" width=300>
#
# ## Properties of Diagnostic Tests
#
# The two main properties of a diagnostic test are <font color="mediumseagreen">**sensitivity**</font> and <font color="mediumseagreen">**specificity**</font>.
#
# - <font color="mediumseagreen">**Sensitivity**</font> is the **probability that a patient will have a positive test result if they have the disease**.  We can describe this as a conditional probability: $P(T+|D+)$.
# - <font color="mediumseagreen">**Specificity**</font> is the **probability that a patient will have a negative result if they do not have the disease**.  It is described by: $P(T-|D-)$.
#
# These test properties can be measured by a clinical study using a sample of patients who are known to have the disease and a sample of healthy controls.

# %% [markdown]
# ### <a name="05ex-roll">Example: Calculating sensitivity and specificity of a new diagnostic test</a>
#
# ----
#
# A noninvasive test for pulmonary hypertension would enable clinicians to perform fewer catheterizations, which in turn would save time and money and greatly reduce patient stress. Researchers at CU Anschutz developed one such noninvasive test based on echocardiographic imaging measurements (EI). <font size="2">**Citation:** </font> [<font size="2"> Maria, M. V. D. et al. Echocardiographic Estimation of Right Ventricular Stroke Work in Children with Pulmonary Arterial Hypertension: Comparison with Invasive Measurements. J. Am. Soc. Echocardiogr. 28, 1350–1357 (2015) </font>](https://doi.org/10.1016/j.echo.2015.07.017).
#
# A small clinical trial was conducted to determine how well this new noninvasive test worked. The study involved 41 patients with pulmonary hypertension and 12 healthy patients.
# - Out of 41 patients who have the disease:
#      - 30 tested positive and 11 tested negative
# - Out of 12 healthy patients:
#      - 6 tested positive and 6 tested negative
#
# The results of the trial are summarized in the table below.
#
# <figure>
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/SensSpecImage.png" width="400">
#
# </figure>
#
# <br>

# %% [markdown]
# ## <a name="05q1">Question 1</a>
#
# ----
#
# Calculate the **sensitivity** of the diagnostic test $P(T+|D+)$.  Remember the property of conditional probability: $\displaystyle P(A | B) = \frac{P(A \cap B)}{P(B)}$

# %% [markdown]
# ### <a name="05ans1">Solution to Question 1</a>
#
# ----
#
#
# </br></br>

# %% [markdown]
# ## <a name="05q2">Question 2</a>
#
# ----
#
# Calculate the specificity of the diagnostic test $P(T-|D-)$.

# %% [markdown]
# ### <a name="O5ans2">Solution to Question 2</a>
#
# ----
#
#
#
# </br></br>

# %% [markdown]
# # <a name="O5notation">Bayes' Theorem</a>
#
# ----
#
# We've seen that that a conditional probability changes what subset of the sample space we care about based on making an assumption. In the case of P(A|B), we care about the probability that event A happens assuming that event B already happened.
#
# $P(A|B) = \frac{P(A \cap B)}{P(B)}$
#
# <img src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/a_given_b.png" width=300>
#
# Similarly, $P(B|A) = \frac{P(B \cap A)}{P(A)}$.
#
# <img src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/b_given_a.png" width=300>
#
# Well, if we solve each of those for P(A n B) and substitute those in our original equations, we get these very useful equations in return:
#
# $P(A|B) = \frac{P(B|A)*P(A)}{P(B)}$
#
# $P(B|A) = \frac{P(A|B)*P(B)}{P(A)}$
#
# Why are these helpful? **All this means that P(A|B) and P(B|A) are related to each other.**
#
# Sometimes it's easier to calculate or estimate P(A|B) than P(B|A), or the other way around. The important part is that **if we manage to get information about one of them, we also get information about the other**.
#
# Bayes' Theorem is essentially a rule for how conditional probabilities should change when given new data - a way to update your beliefs when presented with new infomation. It is the basis for something called <font color="mediumseagreen">**inference**</font>: *the process of using evidence and reasoning to make educated guesses about something that isn't guaranteed or directly stated.* That might sound complicated, but you actually already do this every single day, multiple times a day.
# - You cannot say with 100% certainty that the bus will be late tomorrow morning, but since it's been ~2 minutes late most days for the last month, you may infer that it will likely happen again.
# - You cannot be 100% sure that the milk you have in your fridge that is now one day past its sell-by date is fine to drink, but since you've drank 1-day-past-date milk several times before and been fine, you could infer that you'll be fine this time.
#
# Every time that you are making assumptions about the world around you based on previous experience, you are using inference.

# %% [markdown]
# # <a name="O5notation">Predictive Values</a>
#
# ----
#
# If a patient receives a positive test result from a screening test, it would be useful to know the probability that they actually DO have the disease. This probability is called the <font color="mediumseagreen">**Positive Predictive Value** (PPV)</font>: $P(D+|T+)$.
#
# This is **not** the same as the sensitivity of the test: $P(T+|D+)$.
#
# <br>
#
# Likewise, if they test negative, it would be useful to know what is the probability that they do not have the disease. This is the <font color="mediumseagreen">**Negative Predictive Value** (NPV)</font>: $P(D-|T-)$.
#
# <br>
#
# In order to find these predictive values, we need not only the sensitivity and specificity of the test, but the disease prevalence, $P(D+)$. The equations relating these comes from Bayes' Rule:
#
# <br>
#
# $$PPV = \frac{\text{Sensitivity} \cdot P(D+)}{\text{Sensitivity} \cdot P(D+) + (1 - \text{Specificity}) \cdot (1 - P(D+))}$$
#
# <br>
#
# $$NPV = \frac{\text{Specificity} \cdot (1-P(D+))}{\text{Specificity} \cdot (1-P(D+)) + (1-\text{Sensitivity}) \cdot P(D+) }$$

# %% [markdown]
# ## <a name="O5q3">Question 3</a>
#
# ----
#
#
# A rapid flu test based on a saliva sample has a sensitivity of 89% and a specificity of 95%. The prevalence of flu in the county in which you live is 5%. If you have a positive test result, what is the probability you have flu?
#
#
#
# <br>

# %% [markdown]
# ### <a name="O5ans3">Solution to Question 3</a>
#
# ----
#
#
#
# </br></br>

# %% [markdown]
# ## <a name="O5q4">Question 4</a>
#
# ----
#
#
# Let's say instead that you live in a county with a higher prevalence of flu of 15%.
# - If you have a positive test result, what is the probability you have flu?
#
#
#
# <br>

# %% [markdown]
# ### <a name="O5ans4">Solution to Question 4</a>
#
# ----
#
#
# </br></br>

# %% [markdown]
# # <a name="O5notation">Frequentist vs Bayesian Inference</a>
#
# ----
#
# The **probability of an event** is the *relative frequency of the event occuring over an indefinitely large number of trials*. For example, if you toss a fair coin and calculate the # of heads you saw /total # of tosses, it will approach 1/2 for many tosses (or "trials").
#
# This definition forms the basis for the <font color="mediumseagreen">**frequentist**</font> method of inference, which is the main approach to statistical inference used in statistical practice.
#
# **However**, Bayes had other ideas about inference. He didn't believe that probability should be defined by frequency - he considered it a theoretical concept that can never be realized in practice. Instead, Bayesians consider two types of probability: a *prior probability* and a *posterior probability*.
#
# - The <font color="mediumseagreen">**prior probability**</font> of an event is the observer's best guess of the probability of that event without (or before) seeing any data related to that event.
#
# - The <font color="mediumseagreen">**posterior probability**</font> of an event is the updated likelihood that an event will occur after collecting some empirical data. You're essentially integrating new information related to that event to your prior probability.
#
# From the previous flu example, the probability that a random person from the county you live has the flu is given by the prevelence of flu or P(D+) = 0.15. This is the **prior probability** - your probability of having the flu is 0.15 since that's the information you currently have. If you are then tested it comes back positive, your probability of having the flu increases. This is the **posterior probability**.

# %% [markdown]
# # <a name="O5notation">Receiver Operator Characteristics (ROC) Curve</a>
#
# ----
#
# Consider the first example concerning a non-invasive diagnostic test for pulmonary hypertension (PH). The test uses Echocardiographic Imaging (EI) to measure the pulmonary artery diameter $X_{d}$ which ranges from 0.5 to 4. A larger artery diameter means the person is at risk of having PH.
#
# For clinical testing, we need to choose a diagnostic cutoff value for $X_{d}$, basically a value that we use as threshold to decide if the test result is positive or negative.
#
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/ROCexplanation.png" width="700">
#
# In the image above, the vertical lines represent different cutoff values. If you look carefully, you will notice that **changing the threshold changes the # of true positives (TP), true negatives (TN), false positives (FP), and false negatives (FN).** Seeing how these change based on a variety of cutoff values would be very helpful in deciding what that cutoff should be.
#
# Instead of plotting many different distributions, we can create a <font color="mediumseagreen"> **Receiver Operator Characteristics** (ROC)</font> curve to get a better idea of the accuracy of the test. In a general sense, An **ROC curve is a visual way to see how well a test distinguishes between two options at different cutoff values** - the tradeoff between sensitivity and specificity.
#
# To create a ROC curve, you calculate the test sensitivity and specificity at different cutoff values. Let's do an example with the non-invasive test for PH.
#
# First, we set our cutoff value to be $X_{d}$ = 4. In this case, the cutoff is set so high that no one in the study tests positive and everyone tests negative.
#
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/ROCcurveXd4.png" width="400">
#
# Sensitivity is the number of true positives (i.e. both disease positive and test positive) divided by number of disease positives:
#
# - Sensitivity = 0/(0+41) = 0
#
# Specificity is the number of true negatives (i.e. both disease negative and test negative) divided by the number of disease negatives:
#
# - Specificity = 12/(0+12) = 1
#
# So, for cutoff of 4,
# - Sensitivity = 0
# - 1 - Specificity = 1 - 1 = 0
#
# Our point on the ROC curve would be **(0,0)**.
#
# <br>
#
# Next, we can choose a cutoff value that is at the lowest value of $X_{d}$ so that everyone is test positive (i.e. cutoff of $X_{d}$ = 0)
#
# Our contingency table would then be:
#
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/ROCcurveXd0.png" width="400">
#
# - Sensitivity = 41/(41+0) = 1
# - Specificity = 0/(12+0) = 0
#
# For cutoff of 0,
# - Sensitivity = 1
# - 1 - Specificity = 1 - 0 = 1
#
# Our point on the ROC curve would be **(1,1)**.
#
# <br>
#
# We now have the our two extremes. Note that all ROC curves include the points **(0,0)** and **(1,1)**.
#
# <br>
#
# Now we vary the cutoff value incrementally and calculate the sensitivity and sensitivity with each change building up the ROC curve.
#
# For cutoff $X_d$ = 2.5, 1:
#
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/ROCcurveXd1and2p5.png" width="400">

# %% [markdown]
# ## <a name="O5q5">Question 5</a>
#
# ----
#
#
# What are the points on the ROC curve for cutoffs of $X_d$ = 1 and $X_d$ = 2.5?
#
#
# <br>

# %% [markdown]
# ### <a name="O5ans5">Solution to Question 5</a>
#
# ----
#
# <br>
# The points on the ROC curve are:
#
# For $X_d$ =1: __
#
# For $X_d$ = 2.5: __
# <br>

# %%
# in case you want to use this for calculations

# %% [markdown]
# ## <a name="O5q6">Question 6</a>
#
# ----
#
#
# Create a plot of the ROC curve from the points you calculated.
#
#
# <br>

# %%
# code cell for creating ROC curve.  Use plot().

# %% [markdown]
# # <a name="O4notation">Area under the Curve</a>
#
# ---
#
# Suppose you did many tests and plotted the frequency distribution of all $X_d$ values taken from people who have PH and those who do not.  The plot below shows two different distributions below for those who do have the disease and who do not.
#
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/ROCexplanation.png" width="600">
#
# Figure A and B show the same distributions but with different threshold values (vertical lines), showing the tradeoff between sensitivity and specificity as you change the cutoff. These are the changes that the ROC curve is describing - but is there a way to summarize all that information better?
#
# The <font color="mediumseagreen"> **Area Under the ROC Curve** (AUC) </font> is a useful property that can tell you more about whether your test is accurate. **It basically tells you that the test is accurate x% of the time.**
#
# If the test is perfect, the area under the curve would be 1, or an accuracy of 100% - i.e. always correctly identifies whether the person has the disease or not.  If you have a test that has some false positives and false negatives, then the AUC is less than 1.
#
# The plot below describes how different distributions change the ROC curve to give you some intutition.
#
# <img
# src="https://raw.githubusercontent.com/gibsonea/Biostats/main/Images/ROCarea.png" width="700">

# %% [markdown]
# ### <a name="O4notation">The Trapezoidal Rule</a>
#
# ---
#
# This is a numerical method you might have learned in calculus - we use small trapezoids to estimate an integral, which is just the area under a curve. In R, you can use the `trapz()` function in the `pracma` library.

# %%
# load the library
install.packages("pracma")
library(pracma)

# see the trapz() documentation
?trapz

# %% [markdown]
# ## <a name="O5q7">Question 7</a>
#
# ----
#
#
# Use the points on the ROC curve you calculated in Question 6 to get the area under the curve (AUC) using the trapezoidal rule.
#
#
# <br>

# %%
# Use this code cell to calculate the AUC

# %% [markdown]
# ### <a name="O5ans5">Solution to Question 7</a>
#
# ----
#
#
#
# <br><br>

# %% [markdown]
# ** Note that in this example, we have only calculated points on the ROC for just a few values of the threshold.  Typically you would want to include every data point in your sample in the calculation of a ROC curve.

# %% [markdown]
# ## <a name="O5q8">Question 8</a>
#
# ----
#
#
# Based on your calculated accuracy, do you think this would be a good clinical test? Why?
#
#
#
# <br>

# %% [markdown]
# ### <a name="O5ans8">Solution to Question 8</a>
#
# ----
#
#
#
# <br><br>

# %% [markdown]
# # <a name="CC License">Creative Commons License Information</a>
# ---
#
#
# ![Creative Commons
# License](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
#
# Notebook developed by Emily Gibson and Skylar Suarez based on Introduction to Biostatistics 8th edition by Bernard Rosner
