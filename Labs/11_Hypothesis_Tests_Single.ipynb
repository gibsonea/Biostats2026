# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonea/Biostats2026/blob/main/Labs/11_Hypothesis_Tests_Single.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <a name="23intro">Hypothesis Testing</a>
#
# ---
#
# Hypothesis tests are, in a way, the heart of statistical data analysis. If you have a hypothesis, you generally have to test it before making any claims that it is correct, and to do that, we need some evidence. Hypothesis tests are a way to do exactly that.
#
# A <font color="dodgerblue">**hypothesis test**</font> is a <font color="dodgerblue">structured way to use data to evaluate claims, balancing evidence against the possibility of random variation</font>. It helps us make decisions or draw conclusions about a population.
#
# Like we discussed last week with confidence intervals, we usually do not have access to an entire population, only a sample of it. Hypothesis tests *help us decide whether the patterns we see in that sample are strong enough to conclude something real is happening* or whether they are due to random chance.
#
# There are many different types of hypothesis tests that each test for different things. In fact, a lot of statistics functions you may have used in Python or other languages are likely doing hypothesis tests under the hood!
#
# There are two major categories of hypothesis tests: **parametric** and **non-parametric**.
# - <font color="dodgerblue">**Parametric**</font> tests *assume data follows a specific distribution*, using parameters like mean, standard deviation, etc. These tests are very useful for continuous, normal data.
# - <font color="dodgerblue">**Non-parametric**</font> tests *do NOT assume anything about the data distributions*. These tests are more useful for skewed or very small datasets.
#
# For now, we will focus on parametric tests.

# %% [markdown]
# # <a> Key Components of Hypothesis Tests</a>
# ---
#
# Before we dive into how to actually conduct a hypothesis test, we should cover the key components to understand what calculations we will need to do.
#
# First, the basics:
#
# - **Information on sample and context**: what group or situation we're dealing with.
#     - E.g., "a sample of 30 male patients aged 50-60 years old"
# - **Variables**: the measurable elements involved (independent and dependent variables).
#     - E.g., "low-sugar diet (independent) may affect blood glucose levels (dependent)"
# - **Claim or relationship**: A specific statement about how the variables relate - *the thing we want to test for!*
#     - E.g., "switching to a low-sugar diet changes the blood glucose levels of 50-60 year old males"
#
# So how do we test the claim? We need to construct **hypotheses** that we can test directly. A hypothesis test usually involves two hypotheses:
# - The <font color="dodgerblue">**Null Hypothesis ($H_0$)**</font> is the *default assumption* - typically, this is "no difference" or "no effect". <font color="mediumseagreen">In hypothesis testing, we assume that $H_0$ is true, then try to disprove it</font>.
#     - E.g., "the blood glucose levels of 50-60 year old males on a low-sugar diet is **the same** as their blood glucose levels were prior to switching from a regular diet"
# - The <font color="dodgerblue">**Alternative Hypothesis ($H_1$)**</font> is *the claim you are testing*, usually the opposite of $H_0$ - typically, this is "there is a difference" or "there is an effect".
#     - E.g., "the blood glucose levels of 50-60 year old males on a low-sugar diet is **NOT the same** as their blood glucose levels were prior to switching from a regular diet"
#
# > <font size="2">You might notice that the null hypothesis that we are testing is different from the claim made at the beginning. This is because it's much easier to assess evidence against a claim than to definitively prove it true. For more information and intuition behind this, see [Appendix A](#11appendixA).</font>
#
# So how do we try to disprove $H_0$? We need a few more things...
#
# - <font color="dodgerblue">**Test statistic**</font>: A single-number summary of your data that measures how far your data is from what you should expect to see.
#     - *This is calculated differently depending on the test*. For example, if your data is normal and has a large sample size, you might calculate a **z-score**, while if you have a small dataset, you might calculate a **t-statistic**. We will explore more of these as we move through the course.
#
# The test statistic alone is not enough to interpret whether our data has statistical significance or not. For that, we need two other things: a <font color="dodgerblue">**p-value**</font> and a <font color="dodgerblue">**significance level**</font>. More on these in a bit!
#
# <br>

# %% [markdown]
# #<a> Question 1 </a>
# ---
#
# Write out the null and alternate hypotheses for each of the scenarios below.

# %% [markdown]
# ## <a> Question 1a </a>
# ---
#
# A local health department is tasked with finding out whether the incidence of flu in their community this past season is comparable to the national average incidence of flu for the last 50 seasons.
#
# <br>

# %% [markdown]
# ### <a> Solution to Question 1a </a>
# ---
#
# $H_0$: ?
#
# $H_1$: ?
#
# <br>

# %% [markdown]
# ## <a> Question 1b </a>
# ---
#
# Bob thinks that his monthly utility bills for the past year are not representative of his neighbourhood's average monthly bill over the past 20 years.
#
# <br>

# %% [markdown]
# ### <a> Solution to Question 1a </a>
# ---
#
# $H_0$: ?
#
# $H_1$: ?
#
# <br>

# %% [markdown]
# # <a> p-values & Significance Levels</a>
# ---
#
# As we mentioned before, the test statistic does tell us how far our sample data is from the population we are testing against, but it's not enough to decide whether what effect/difference we're seeing is "real" or due to random chance. Both significance levels and p-values help answer these questions - they tell us whether our findings are *statistically significant*.
#
# ### <a>$p$-value<a>
#
# A <font color="dodgerblue">**$p$-value**</font> answers the question: *"if $H_0$ were true, how rare is the sample data we observed?"* by telling you the **probability** of getting the sample data you observed by random chance. You can think of it as a measure of "extremeness", or how strong the evidence against $H_0$ is.
#
# <font color="mediumseagreen">**When conducting a hypothesis test, this will be the value you report alongside your conclusions.**</font>
#
# For example, if your $p$-value is 0.15, it means that your sample is in the 15% most extreme samples we would expect to see if $H_0$ is true.Or in other words, there is a 15% probability that you would end up with this result.
#
# - A ***small*** p-value → the sample data is **unlikely** under the assumption that $H_0$ ("there is no difference") is true.
# - A ***large*** p-value → the sample data is **likely** under the assumption that $H_0$ is true.
#
# As an example, imagine flipping a fair coin:
# - If you get heads 10 out of 10 times, that's very rare since the probability of that is very low.
# - If you get heads 4 out of 10 times, that's not rare since the probability of that is pretty high - in fact, that's pretty close to what you would expect to see.
#
# These concepts are visually explained in the picture below.
#
# <figure>
# <img src="https://github.com/gibsonea/Biostats/blob/main/Images/hypotest_pval.png?raw=true" width=500/>
# </figure>
#
# We get this p-value by <font color="dodgerblue">converting our test statistic into the probability of seeing values at least as extreme as that within the probability distribution for our test</font> and multiplying it by 2 (to account for the two tails of the distribution).
#
# - Using our "blood glucose changes with a low-sugar diet" example, imagine you collect your data and find out that your test statistic is -1.37. This means that your data is -1.37 standard deviations away from what you expected to see. To translate this into a probability, we look it up and find that the probability of seeing values at least that far out from the center is $\approx$0.09 x 2 $\approx$ 0.18.
#
# But it's not just enough to calculate the probability - we have to decide whether that probability is "significant" enough to make a judgement on it (i.e. to accept or reject the null hypothesis). Enter...
#
# ### <a>Significance Level</a>
#
# A <font color="dodgerblue">**significance level $\alpha$**</font> in a hypothesis test is similar to a confidence interval's $\alpha$. It is a sort of threshold you choose that determines when to reject $H_0$ - we are essentially choosing how extreme our data would have to be for us to consider it enough evidence to reject $H_0$. Another way to think of it is  how small the $p$-value would have to be to say that the evidence against $H_0$ is enough to reject it.</font>.
#
# But how do we know whether our data is extreme enough? We need to set a numerical threshold - an actual boundary point that determines the when to reject $H_0$. The value within the distribution that marks this cutoff point is called the <font color="dodgerblue">**critical value**</font>.
# - For a situation where you use a normal distribution (i.e. large sample size), this would be the z-score that corresponds to a certain $\alpha$ value. In biostatistics we typically define that threshold as $\alpha$ = 0.05. The critical value would be $z_{\alpha/2}$ = $z_{0.025}$ = 1.96)
# - If your test requires a Students' t distribution (i.e. small sample size), this would be the t statistic that corresponds to your $\alpha$ value and degrees of freedom for your data (e.g., for a 20-observation sample and $\alpha$ = 0.05, the critical value would be $t_{\alpha/2, \,df}$ = $t_{0.025, \,19}$ = 2.093)
#
# These concepts are visually explained in the picture below.
#
# <figure>
# <img src="https://github.com/gibsonea/Biostats/blob/main/Images/hypotest_siglev.png?raw=true" width=500/>
# </figure>
#
# For biostatistics, just like with confidence intervals, <font color="dodgerblue">*the most widely used $\alpha$ is **0.05***</font> (split into two tails, on either side). This means that our data will have to be in the 5% most extreme values possible for us to consider it enough evidence to reject $H_0$.
#
# > <font color="red" size="4">**If you are not explicitly given a significance level for your test, always assume that alpha is 0.05.**</font>
#
# ### <a>Two-Tailed Test</a>
#
# When we split the alpha into the two tails like this, we call it a <font color="dodgerblue">**two-tailed** hypothesis test</font>. **A two-tailed test looks for extreme results in both directions**, so *unusually high or unusually low observations can both count as evidence against $H_0$*.
#
# <font color="mediumseagreen">*Note: The significance level is not something we compute, it's something we choose prior to our analysis. Do NOT first calculate the p-value, and then retroactively choose the significance level to ensure the result is significant!*</font>

# %% [markdown]
# # Putting it all together
#
# Since the significance level $\alpha$ gives us the threshold that our observation must cross to be considered "too extreme" (the critical value), we call the area under the curve that represents that probability the <font color="tomato">**rejection region**</font>.
#
# **If our observation's p-value falls within the rejection region, we can reject $H_0$ since the evidence is telling us that our observation is too unlikely to be due to random chance.**
#
# So... Once we collect our data and find our data's test statistic, we can convert it to a p-value and we can see whether it falls within the rejection region or not.
#
# <figure>
# <img src="https://github.com/gibsonea/Biostats/blob/main/Images/hypo_test_sum.png?raw=true" width=500/>
# </figure>
#
# If it does, we have enough evidence to say that $H_0$ is very unlikely to be true (e.g., "there is a difference!")
#
# ## <a>Summarizing the Results</a>
#
# Numerically, the way we can tell whether the p-value is within the rejection region or not is by comparing the p-value to $\alpha$. There are two possible outcomes:
#
# - If your <font color="tomato"> **p-value $\leq \alpha$**</font>, it falls within the <font color="tomato">red region</font> and we <font color="tomato">**reject $H_0$**</font>. This means that our result is *statistically significant*, and we accept the competing claim made in $H_1$.
# - If your <font color="turquoise">**p-value $> \alpha$**</font>, it falls within the <font color="turquoise">blue region</font> and we <font color="turquoise">**fail to reject $H_0$**</font>. *This means our test  is inconclusive regarding $H_0$ and $H_1$*.
#
# In the end, we want to be sure we communicate the results **clearly**,
# in **proper context**, to a more **general audience** that may not have
# an advanced background in statistics and mathematics.
#
# When we report our findings, <font color="mediumseagreen">we always want to state how our $p$-value compared with $\alpha$</font>.
# - For example, if we used $\alpha$ = 0.05 and our $p$-value fell in the rejection region, we would add something like (p $\le$ 0.05) at the end of our statement. In scientific publications, you often state what the p-value is and indicate its on any data plots. For example: a p-value between 0.01 and 0.05 is significant and denoted by a single astrix, *. A p value between 0.01 and 0.001 is highly significant,denoted by a double astrix ** and a value less than 0.001 is extremely significant ***.

# %% [markdown]
# # <a name="hypo_test_gen_proc">The General Process of Hypothesis Tests</a>
# ---
#
# There are MANY different hypothesis tests, and in this class we will only cover a few of them. Still, most hypothesis tests follow the same general approach:
#
# 1. Choose your significance level, the cutoff for "strong enough evidence to reject $H_0$". The default is $\alpha$ = 0.05.
#
# 2. Outline what you know about your sample(s) and/or population.
#
# 3. Choose the appropriate test based on what you know and the question you want to answer.
#
# 4. *Define the null ($H_0$) and alternative ($H_1$) hypotheses*. We will assume that $H_0$ is true and will try to disprove it.
#     - $H_0$: "a drug has no effect", "two treatments are equally effective"...
#     - $H_1$: "a drug does have an effect", "two treatments have different effect"...
#
# 5. *Calculate a test statistic*, a single number that measures how far your data is from what $H_0$ predicts. How we calculate this number differs depending on the specific test we're doing, but the idea is the same.
#
# 6. *Calculate the p-value* from the test statistic, the probability of our data being at least this extreme if $H_0$ is true.
#
# 7. *Decide whether to reject $H_0$* or not by comparing the p-value (our evidence of extremism) to the significance level (the pre-determined cutoff for extremism).
#
# 8. Interpret and summarize the results of our test within the context of the original question, including how the $p$-value compared to $\alpha$.
#
#
# > <font color="mediumseagreen">In short, we assume "no effect/difference", check how unlikely our data would be under that assumption, and then decide whether our data is extreme enough to question the "no effect/difference" claim.</font>

# %% [markdown]
# ## <a name="11q2">Question 2</a>
#
# ---
#
#
# <figure>
# <img
# src="https://upload.wikimedia.org/wikipedia/commons/4/4f/Hurricane-en.svg"
# alt="Tropical Cyclone Structure" width = "60%"/>
# <figcaption aria-hidden="true">
# Credit: Kelvinsong, <a
# href="https://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>, via
# Wikimedia Commons
# </figcaption>
# </figure>
#
#
# Pressure is a common measurement used to characterize the strength of a
# storm. The lower the storm pressure, the higher the wind speeds, and the
# more dangerous the storm. Let $\mu$ denote the mean pressure (in
# millibars) of all storms in the North Atlantic. Suppose we set up the
# following hypothesis to test claims about the value of $\mu$.
#
# -   $H_0$: $\mu = 950$. The mean pressure of all storms in the North Atlantic is 950 millibars.
# -   $H_1$: $\mu \ne 950$. The mean pressure of all storms in the North Atlantic is not 950 millibars.
#
# We collect a random sample of $n$ storm pressure observations. The sample mean turns out to be different from 950 millibars, with a p-value of $0.012$.

# %% [markdown]
# ### <a name="11q2a">Question 2a</a>
#
# ---
#
# Summarize the results if we perform the hypothesis test using a 5%
# significance level. Be sure to explain in the context of the example
# using terminology a more general audience would understand.

# %% [markdown]
# #### <a name="11sol2a">Solution to Question 2a</a>
#
# ---
#
#
#
#
# <br>

# %% [markdown]
# ### <a name="11q2b">Question 2b</a>
#
# ---
#
# Summarize the results if we perform the hypothesis test using a 10%
# significance level. Be sure to explain in the context of the example
# using terminology a more general audience would understand.

# %% [markdown]
# #### <a name="11sol2b">Solution to Question 2b</a>
#
# ---

# %% [markdown]
# ### <a name="11q2c">Question 2c</a>
#
# ---
#
# Summarize the results if we perform the hypothesis test using a 1%
# significance level. Be sure to explain in the context of the example
# using terminology a more general audience would understand.

# %% [markdown]
# #### <a name="11sol2c">Solution to Question 2c</a>
#
# ---
#
#
#
#
# <br>

# %% [markdown]
# # <a> The two-tailed One-sample $z$-test </a>
# ---
#
# This is the first (and simplest) type of hypothesis test we'll cover.
#
# ### <a>The basic idea</a>
#
# We use a two-tailed one-sample $z$-test when we want to answer the question:
#
# > <font color="dodgerblue">*"Is my sample mean different from a claimed/known population mean value?"*</font>
#
# Some example questions we can answer with this test:
# - "Is the cell division rate of my cancerous skin cell culture different from the established average cell division rate of non-cancerous skin cells?"
# - "Is the protein content of my shipment of granola bars actually what the company claims it is?"
# - "Is the blood glucose level of young adult women on a low-sugar diet lower than the national average?"
#
# ### When to use this test
#
# To use a two-tailed one-sample $z$-test properly, we must have data from a <font color="tomato">**relatively large sample ($n \geq 200$)**</font> and <font color="tomato">**know the population mean $\mu$**</font> we are comparing to our sample.
#
# ### <a>What we know</a>
#
# - The sample mean $\bar{x}$
# - The sample standard deviation $s$
# - The sample size $n$
# - The known study population mean value $\mu$
#
# ### <a>Hypotheses</a>
#
# - Null hypothesis $H_0$: $\mu_0 = \mu$ (meaning our sample population mean $\mu_0$ (note: this is unknown, but we are estimating it from our sample data) is the same as the population we are comparing $\mu$)
# - Alternative hypothesis $H_1$: $\mu_0 \neq \mu$ (meaning our sample population mean $\mu_0$ is different from the population mean $\mu$)
#
# ### <a>Test Statistic</a>
#
# We use the standard normal distribution to calculate the test statistic (z) using the equation:
#
# $$\,\,\,\, \large z = \frac{\bar{x}-\mu}{\frac{s}{\sqrt{n}}} $$
#
# This tells you how far your sample mean is from the known value, measured in standard errors (the denominator). Just like with z-scores, a larger $z$ means your sample mean $\bar{x}$ is further from the population mean value $\mu$.
#
# To convert this $z$ statistic to a $p$-value:
# 1. Find the probability of seeing that a sample mean that is **at least as extreme**. You can do this two ways:
#     - Use a standard normal distribution table to find the probability
#     - Use the R function call `pnorm(abs(z), lower.tail = FALSE)`
# 2. **Multiply the probability you get by two** to account for the two tails of the distribution.
#
# ### <a>Interpreting Results</a>
#
# <figure>
# <img src="https://github.com/gibsonea/Biostats/blob/main/Images/hypo_test_sum.png?raw=true" width=400/>
# </figure>
#
# Compare your p-value to your $\alpha$:
#
# - If your <font color="tomato">**p-value $\leq \alpha$**</font>, it falls within the <font color="tomato">rejection region</font> and we <font color="tomato">**reject $H_0$**</font>.
#     - We conclude that our sample population mean $\mu_0$ is NOT the same as the known population mean value $\mu$.
# - If your <font color="turquoise">**p-value $> \alpha$**</font>, it falls within the <font color="turquoise">blue region</font> and we <font color="turquoise">**fail to reject $H_0$**</font>.
#     - We cannot conclude anything about our sample population mean $\mu_0$ in relation to the known population mean value $\mu$.
#     - Failing to reject $H_0$ does not prove the means are equal, it just means you do not have strong enough evidence to conclude that they are different.
#
# Remember to write your interpretation within the proper context of the problem and to include how the $p$-value compared with the $\alpha$.
#
# <br><br>

# %% [markdown]
# # <a> Two-Tailed One-Sample Hypothesis $z$-Test Example </a>
#
# ----
#
# A grocery store chain purchases a large batch of pre-made cakes from a large manufacturer. The manufacturer claims that their cakes weigh 500 grams.
#
# > The grocery store wants to know if the cakes they received comply with the manufacturer's claim, so they weigh each cake in their 250-unit order and note that their average cake weight is **498 grams** with a standard deviation of 10 grams.
#
# Following [the steps outlined before](#hypo_test_gen_proc):
#
# ### Step 1: Choose significance level
# Let's use the standard $\alpha$ = 0.05 for this test.
#
# ### Step 2: Outline what we know
# - The sample average weight $\bar{x}$ = 498 g
# - The sample standard deviation is s = 10 g
# - The sample size $n$ = 250
# - The manufacturer claimed average weight $\mu$ = 500 g
#
# ### Step 3: Choose the appropriate test
# Since we are comparing our sample to a known population mean it is a one-sample test. Since we have a sample size larger than 200, we will use the z-statistic. You should choose a two-tailed one-sample $z$-test to solve this question.
#
# ### Step 4: Define your hypotheses
# - $H_0$: $\mu_0$ = 500 g (we will assume this is correct and try to disprove it)
# - $H_1$: $\mu_0 \neq$ 500 g
#
# ### Step 5: Calculate your test statistic
#
# $\,\,\,\, \large z = \frac{\bar{x}-\mu}{s/\sqrt{n}} = \frac{498-500}{10/\sqrt{250}} = \frac{-2}{0.63} = -3.16$
#
# This means our sample mean is -3.16 standard errors away from the population mean $\mu$.
#
# ### Step 6: Calculate the $p$-value from the test statistic
#
# We want to know the probability of seeing values that are at least $\pm$3.16 standard deviations away from the mean, so we calculate $P(z \leq -3.16)$ using the R function `pnorm()`.
#
# ```
# pnorm(abs(-3.16),lower.tail=FALSE)
# ```
#
# We find that $P(z \leq -3.16) = 0.00078$
#
# Therefore the p-value = 0.00078 * 2 = 0.00156
#
# ### Step 7: Decide whether to reject $H_0$
#
# <figure>
# <img src="https://github.com/gibsonea/Biostats/blob/main/Images/hypo_test_ex2.png?raw=true" width=400/>
# </figure>
#
# Our p-value = 0.00156 is less than $\alpha$ = 0.05, so we reject $H_0$.
#
# ### Step 8: Interpret the results in the context of our data
#
# There is strong statistical evidence that the average cake weight in the order is different than the manufacturer claim of 500 g ($p \leq 0.05$).

# %% [markdown]
# ## <a name="23q3">Question 3</a>
#
# ---
#
# The mean height of all adult males in the United Kingdom is claimed<sup>2</sup> to be $68.5$ inches.
#
# A physician suspects males in her town seem to have a different height than average when compared to the population of all adult males in the UK. She collects data from a random sample of $n=300$ adult males from the town and calculates the mean height of the sample is $68.3$ inches with a standard deviation of $2.5$ inches.
#
#
# <font size=1>2. [“Height, Weight, and Body Mass of the British Population Since 1820”](https://www.nber.org/system/files/working_papers/h0108/h0108.pdf) by Roderick Floud, National Bureau of of Economic Research, October 1998.</font>

# %% [markdown]
# ### <a name="23q3b">Question 3a</a>
#
# ---
#
# Write out what you know based on the question.

# %% [markdown]
# #### <a name="11sol3a">Solution to Question 3a</a>
#
# ---
#
#
#
#
# <br>

# %% [markdown]
# ### <a name="23q3b">Question 3b</a>
#
# ---
#
# What test will you use and why?

# %% [markdown]
# #### <a name="11sol3b">Solution to Question 3b</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="23q3a">Question 3c</a>
#
# ---
#
# Set up the null and alternative hypotheses (both in words and using
# appropriate notation) to test the physician's claim that adult males in
# the town have a different height than the national average height for all adult males in the UK.

# %% [markdown]
# #### <a name="11sol3c">Solution to Question 3c</a>
#
# ---
#
# -   $H_0$: ?
#
# -   $H_1$: ?
#
# <br>

# %% [markdown]
# ### <a name="23q3b">Question 3d</a>
#
# ---
#
# Compute the test statistic. Where does the observed sample mean height lie relative to the population mean height?

# %%
# code block

# %% [markdown]
# #### <a name="11sol3d">Solution to Question 3d</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="23q3c3c">Question 3e</a>
#
# ---
#
# Calculate the p-value for the test statistic and compare it to $\alpha$. Does it fall within the rejection region?
#
# <font color="mediumseagreen">*Note: Remember, if not explicitly given, always default to $\alpha$ = 0.05!*

# %% [markdown]
# #### <a name="11sol3e">Solution to Question 3e</a>
#
# ---
#
#
#
#
# <br>

# %%
#code cell

# %% [markdown]
# ### <a name="23q3d">Question 3f</a>
#
# ---
#
# Interpret the result of your hypothesis test within the context of the problem.

# %% [markdown]
# #### <a name="11sol3f">Solution to Question 3f</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# # <a> The two-tailed one-sample $t$-test </a>
# ---
#
# This test answers the same type of questions as the two-tailed one-sample $z$-test we just learned about, but we use the $t$-test instead when...
# - We have data from a relatively <font color="tomato">*small* sample ($n \leq 200$)</font>.
#     - In real world examples of statistics, the *$t$-test tends to be used a lot more than the $z$-test*. Also, since it is a more conservative test (statisticians tend to be conservative folks!) it is used by default.
#
# ### <a>What we know</a>
#
# - The sample mean $\bar{x}$
# - The sample standard deviation $s$
# - The sample size $n$
# - The population mean value $\mu$
#
# The good news is that the hypotheses and how we interpret the results are all the same as the $z$-test! The main difference here is how we calculate the $p$-value.
#
# ### <a>Test Statistic</a>
#
# We use the $t$ distribution to calculate the test statistic using the equation:
#
# $$\,\,\,\, \large t = \frac{\bar{x}-\mu}{\frac{s}{\sqrt{n}}}$$
#
# You might have noticed that the equation for $t$ is practically the same as the equation for $z$, and it tells the same thing. What's new here is how we convert this $t$ statistic to a $p$-value:
# 1. Compute your degrees of freedom $df = n -1$
# 2. Find the probability of seeing that a sample mean that is **at least as extreme as yours** by using the R function call `pt(abs(t), df, lower.tail=FALSE)`.
#
# 3. You still **multiply the probability by two** to account for the two tails of the distribution.
#
# ## Summary of Differences between the two-tailed one-sample $z$ and $t$ tests
#
# | Feature               | $z$-test           | $t$-test                       |
# | --------------------- | ------------------ | ------------------------------ |
# | Population SD (σ)     | Known              | Unknown                        |
# | Distribution used     | Standard normal distribution         | $t$ distribution               |
# | Sample size           | $n \geq 200$ (or σ known) | Small $n \leq 200$         |
# | Shape of distribution | Fixed (doesn't depend on n)             | Wider tails w/lower n (more uncertainty) |
#
# <br><br>

# %% [markdown]
# # <a> Two-Tailed One-Sample Hypothesis $t$-Test Example </a>
#
# ----
#
# A local clinical researcher wants to compare the Denver female type-2 diabetic population's blood glucose level to the national average type-2 female diabetic blood glucose level of 120 mg/dL.
#
# > The researcher collects a **sample** of *45 adult female type 2 diabetic patients at UCHealth and measures their glucose level on a given day*. The sample mean $\bar{x}$ turns out to be **130 mg/dL** and the sample standard deviation $s$ is **30 mg/dL**.
#
# Following [the steps outlined before](#hypo_test_gen_proc):
#
# ### Step 1: Choose significance level
# Let's use the standard $\alpha$ = 0.05 for this test.
#
# ### Step 2: Outline what we know
# - The sample mean blood glucose level $\bar{x}$ = 130 mg/dL
# - The sample standard deviation $s$ = 30 mg/dL
# - The sample size $n$ = 45
# - The national average blood glucose level $\mu$ = 120 mg/dL
#
# ### Step 3: Choose the appropriate test
# Since we are comparing our sample to a known population mean that we know and have a sample size smaller than 200, we will use the two-tailed one-sample $t$-test here.
#
# ### Step 4: Define your hypotheses
# - $H_0$: $\mu_0$ = 120 mg/dL (we will assume this is correct and try to disprove it)
# - $H_1$: $\mu_0 \neq$ 120 mg/dL
#
# ### Step 5: Calculate your test statistic
#
# $\,\,\,\, \large t = \frac{\bar{x}-\mu}{s/\sqrt{n}} = \frac{130-120}{30/\sqrt{45}} = \frac{30}{2.12} = 2.24$
#
# This means our sample mean $\bar{x}$ is 2.24 standard deviations away from the population mean $\mu$ we are comparing it to.
#
# ### Step 6: Calculate the $p$-value from the test statistic
#
# The degrees of freedom $df = n - 1 = 45 - 1 = 44$
#
# We want to know the probability of seeing values that are at least 2.24 standard deviations away from the mean, so we calculate $P(t \geq 2.24)$ using the R function `pt()`.
#
# ```
# pt(2.24, 44, lower.tail=FALSE)
# ```
#
# We find that $P(t \geq 2.24) = 0.015$
#
# Therefore p-value = 0.015 * 2 = 0.03
#
# ### Step 7: Decide whether to reject $H_0$
#
# <figure>
# <img src="https://github.com/gibsonea/Biostats/blob/main/Images/hypo_test_ex1.png?raw=true" width=400/>
# </figure>
#
# Our p-value = 0.03 is less than $\alpha$ = 0.05, so we reject $H_0$.
#
# ### Step 8: Interpret the results in the context of our data
#
# There is strong statistical evidence that the average blood glucose level of the sample of Denver female type-2 diabetic patients is different from the national average of 120 mg/dL ($p \leq 0.05$).
#
# <br><br>

# %% [markdown]
# ## <a name="23sample-press">Picking a Random Sample of Storm Pressures</a>
#
# ---
#
# The `storms` data set is from the [NOAA Hurricane Best Track
# Data](https://www.nhc.noaa.gov/data/#hurdat). We will perform a
# hypothesis test to test claims about the mean storm pressure, so we will
# need to analyze the variable `pressure`.
#
# -   Run the code cell below to load the `dplyr` package.

# %%
library(dplyr)  # load dplyr package

# %% [markdown]
# -   Run the code cell below to pick a random sample of $n=32$ storm pressures from `storms`.

# %%
set.seed(210)  # fixes output for consistent results

my.sample <- sample(storms$pressure, size=32, replace=FALSE)

# %% [markdown]
# ## <a name="23q4">Question 4</a>
#
# ---
#
# It is claimed<sup>3</sup> that the average pressure of all North Atlantic storms is 950 millibars. You believe this claim is inaccurate and would like to show the average pressure of all storms is not 950 millibars.
#
# <font size=1>3. [The University of Arizona Hydrology and Atmospheric Sciences](http://www.atmo.arizona.edu/students/courselinks/fall10/atmo336/lectures/sec2/hurricanes.html),
# accessed July 13, 2023.</font>

# %% [markdown]
# ### <a name="11q4a">Question 4a</a>
#
# ---
#
# Write out what you know based on the question and the sample you just took, stored in `my.sample`.

# %%
# code block

# %% [markdown]
# #### <a name="11sol4a">Solution to Question 4a</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="23q3b">Question 4b</a>
#
# ---
#
# What test will you use and why?

# %% [markdown]
# #### <a name="11sol4b">Solution to Question 4b</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="23q3">Question 4c</a>
#
# ---
#
# Set up the null and alternative hypotheses (both in words and using
# appropriate notation).

# %% [markdown]
# #### <a name="11sol3c">Solution to Question 3c</a>
#
# ---
#
# -   $H_0$: ?
#
# -   $H_1$: ?
#
#
# <br>

# %% [markdown]
# ### <a name="11q4d">Question 4d</a>
#
# ---
#
# Compute the test statistic. Where does the observed sample mean lie relative to the population mean?

# %%
# code block

# %% [markdown]
# #### <a name="11sol4d">Solution to Question 4d</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="11q4e">Question 4e</a>
#
# ---
#
# Calculate the p-value for the test statistic and compare it to $\alpha$. Does it fall within the rejection region?

# %% [markdown]
# #### <a name="11sol4e">Solution to Question 4e</a>
#
# ---
#
#
#
#
#
# <br>

# %%
#code block

# %% [markdown]
# ### <a name="11q4e">Question 4f</a>
#
# ---
#
# Interpret the result of your hypothesis test within the context of the problem.

# %% [markdown]
# #### <a name="11sol3f">Solution to Question 3f</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="11q4g">Question 4g</a>
#
# ---
#
# Interpret the p-value as if you had previously chosen a significance level of 0.01.

# %% [markdown]
# #### <a name="11sol4g">Solution to Question 4g</a>
#
# ---
#
#
#
#
# <br><br>

# %% [markdown]
# ## <a name="11q5">Question 5</a>
#
# ---
#
# For each scenario, indicate which hypothesis test you would use and why.

# %% [markdown]
# ### <a name="11q5a">Question 5a</a>
#
# ---
#
# A nutritionist wants to determine if a new high-protein diet changes the average serum cholesterol levels. Dozens of studies show that the typical average cholesterol level in adults is 200 mg/dL.
#
# The nutritionist collects cholesterol measurements from a sample of 18 participants after following the diet for 3 months and finds a sample mean of 210 mg/dL with a standard deviation of 20 mg/dL.

# %% [markdown]
# #### <a name="11sol5a">Solution to Question 5a</a>
#
# ---
#
#
#
#
# <br>

# %% [markdown]
# ### <a name="11q5b">Question 5b</a>
#
# ---
#
# A laboratory measures the systolic blood pressure of adult patients in a large clinic. Previous national surveys indicate that the mean SBP is 120 mmHg with a known standard deviation of 15 mmHg.
#
# The clinic randomly samples 400 patients and finds that their mean SBP is 122 mmHg with a standard deviation of 8 mmHg.

# %% [markdown]
# #### <a name="11sol5b">Solution to Question 5b</a>
#
# ---
#
#
#
# <br>

# %% [markdown]
# ### <a name="11q5c">Question 5c</a>
#
# ---
#
# A researcher wants to see if a new exercise program affects resting heart rate (RHR). The known average RHR in adults is 72 bpm.
#
# The researcher measures RHR in a sample of 2000 participants after 8 weeks on the program and finds a sample mean of 69 bpm.

# %% [markdown]
# #### <a name="11sol5c">Solution to Question 5c</a>
#
# ---
#
#
#
#
# <br><br>

# %% [markdown]
# <br>
#
# # <a name="11appendixA">Appendix A: Why test the null hypothesis instead of the claim directly?</a>
#
# ---
#
# In hypothesis testing, we initially assume the null hypothesis $H_0$ is true, then try to disprove it. We do this because **it's much easier to assess evidence against a claim than to definitively prove it true**.
#
# - You can reject $H_0$ if evidence is strong.
# - At the same time, you can never truly prove a hypothesis is correct, you can only fail to find evidence against it.
#
# This is similar to a courtroom analogy. You may have heard the phrase "innocent until proven guilty".
#
# > $H_0$ = “the defendant is not guilty", or "the defendant is innocent"
#
# You look for evidence to *reject* that assumption - to say that "defendant IS guilty"
#
# > $H_1$ = "the defendant is guilty"
#
# - If your evidence is sufficient, you reject the $H_0$ claim (the defendant is innocent) in favour of the $H_1$ claim (the defendant is guilty).
# - If evidence is insufficient, you *don't prove* the defendant is innocent, you just *fail to reject* that claim.
#
# **Mathematically, we test $H_0$ because it gives us a clear baseline, we can calculate probabilities under it, and statistics is better at disproving than proving something.**
#
# ## Another way to look at it...
#
# If you're familiar with debates or philosophy, this is a form of the *reductio ad absurdum* argument, which tries to discredit an idea by assuming that it is true, then showing that something contradicts it. Basically, **ff we can show that assuming $H_0$ is true makes something "absurd" happen, then we can reject the idea that $H_0$ is true.**

# %% [markdown]
# <br><br><br>
#
# # <a name="23CC License">Creative Commons License Information</a>
# ---
#
# Author: Skylar Suarez
#
# ![Creative Commons License](https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png)
#
# Adapted from:
#
# *Statistical Methods: Exploring the Uncertain* by [Adam
# Spiegler (University of Colorado Denver)](https://github.com/CU-Denver-MathStats-OER/Statistical-Theory)
# is licensed under a [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License](http://creativecommons.org/licenses/by-nc-sa/4.0/). This work is funded by an [Institutional OER Grant from the Colorado Department of Higher Education (CDHE)](https://cdhe.colorado.gov/educators/administration/institutional-groups/open-educational-resources-in-colorado).
#
# For similar interactive OER materials in other courses funded by this project in the Department of Mathematical and Statistical Sciences at the University of Colorado Denver, visit <https://github.com/CU-Denver-MathStats-OER>.
